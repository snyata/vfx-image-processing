# %% [markdown]
# # Using Style GAN to experiment with Latent Space disentanglement

# %%
# %pip -q install accelerate datasets
# %pip -q install click requests tqdm pyspng ninja imageio-ffmpeg==0.4.3

# %%
import torch
import torchvision
from accelerate import Accelerator
import PIL
import ipywidgets

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"device is {device} and Device Count: {torch.cuda.device_count()}")
# Out:
# device is cpu and Device Count: 0

# %% [markdown]
# ### NERF Library
# https://github.com/nerfstudio-project/nerfstudio

# %%
# %pip -q install nerfstudio

# %% [markdown]
# ### Dataset

# %%
from datasets import load_dataset
dataset = load_dataset("thomagram/StyleNeRF_Datasets")
# Out:
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
